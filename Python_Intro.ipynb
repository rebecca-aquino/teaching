# %% [markdown]
# <a href="https://colab.research.google.com/github/mknomics/teaching/blob/main/Python_Intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# # Variables and Operations

# %% [markdown]
# ## Strings

# %% [markdown]
# **Operations**
#
# "+" add strings
#
# "*" string multiplication
#
# "[n:k]" slice strings
#
# .lower() lower case
#
# .upper()
#
# "\n" New line
#
# print()
#
# .replace()
#
# .find()

# %% [markdown]
# #### Exercise
# Jane and Jack are arguing over who fuzzy wuzzy is.  Their names are followed by an underscore that denotes the order of their conversation.  Example:  Jack_1 is the first time Jack speaks.
#
#
# ![fuzzywuzzy.png](data:image/png;base64,...)

# %% [markdown]
# Slice the Fuz below and use string operations to redefine a new variable for Jack's response
#
# Jack_1 = "Fuzzy Wuzzy was a Bear?"

# %%
Jane_1 = "Was Fuzzy Wuzzy a Bear?"
Jack_1 = ""
# Out:
# 18

# %% [markdown]
# Jane doesn't like this and is a bit upset.  Use string operations on Jack_1 to define Jane's answer = "Fuzzy Wuzzy WAS a Bear"

# %%
Jane_2 =

# %% [markdown]
# Define a new variable "LOVE " and write Jack's response, "I (LOVE)10 times Fuzzy (LOVE FUZZY)10times Wuzzy"
#
# Something Like:
#
# "I LOVE LOVE LOVE .....LOVE FUZZY LOVE FUZZY.....LOVE FUZZY WUZZY"

# %%
L= "LOVE "
Jack_2 =

# %% [markdown]
# Use Jack_2 to define Jane's response, Jane_3 which equals Jack_2 except replace "bear" with "Mouse".  Do it two ways:
#
# a) use slice method just for practice
#
# b) use replace method

# %%
Jane_3a = ""
Jane_3b = ""

# %% [markdown]
# Now use a single print command to put all of their conversations in order.  Make sure to print the variable name and definition on a separate line and all lines are double spaced.

# %%
print("Jack_1" + )
# Out:
# Jack
#
# Jane

# %% [markdown]
# ## Other variable types

# %%
import pandas as pd  #pandas is good for data manipulation.  I rename it here as "pd" to make it easier to call in the script below.  I could rename it anything I want but "pd" is standard

#Import a csv file from a target url:  What is a csv file?  Go to the url below to see the raw data.  columns are separated by a "," and the last column lacks a ","
data_url='https://raw.githubusercontent.com/mknomics/soda/main/soda.csv' # I define a string variable using apostrophe ' but I could ahve also used quotes " ".  I just cannot mix apostophe and quotes in the same line

df = pd.read_csv(data_url) # This line creates a pandas DataFrame that I defined as "df".  I could have called it anything I want

df.head()
df.shape
df.dtypes
# Out:
# id             int64
# date          object
# city          object
# lat          float64
# long         float64
# pop            int64
# shop          object
# brand         object
# container     object
# capacity      object
# price        float64
# quantity       int64
# dtype: object

# %% [markdown]
# ### What is the problem with the data type for "date"?

# %%
# Set my date objects.  
df['date']=pd.to_datetime(df['date']) #make date a datetime object

# Other handy methods
df['year']=pd.DatetimeIndex(df['date']).year # I define a variable 'year' using the DatetimeIndex method
df['month']=pd.DatetimeIndex(df['date']).month # similarly I repeat and define 'month'
