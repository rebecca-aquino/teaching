# %% [markdown]
# <a href="https://colab.research.google.com/github/mknomics/teaching/blob/main/Fun_APIs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Fun APIs

# %% [markdown]
# ## Agify
# predicts your age given your name

# %% [markdown]
# ## Challenge 1:
# write a code using requests.get() method to use the Agify API with your name.
#
# https://api.agify.io/?name=YOUR_NAME
#
#
# parameter: name (required)
#
# ```
# import requests
# url = "api_url"
# request_object = requests.get(url)
# r.json()
# ```

# %%
import requests
url = "https://api.agify.io/?name=matt  "
r = requests.get(url)
r.json()
# Out:
# {'age': 34, 'count': 37614, 'name': 'matt'}

# %% [markdown]
# ## Challenge 2:
# You are in the Game of Thrones and have been accused of stealing a chicken.  Unless you make a case for your innocence, you will be Dragon Food.  Google Translate doesn't translate into Dothraki but all is not lost.  Use the following API to translate, "The Dragon ate the chicken" into Dothraki.
#
# https://funtranslations.com/api/
#
#
# ![Daenerys-Targaryen-Dothraki.jpg](data:image/jpeg;base64,...)

# %%
# your code here

# %% [markdown]
# # APIs of Interest

# %% [markdown]
# ## Google NLP
# https://cloud.google.com/natural-language/docs/
#
# Analyze Sentiment, Entities, Classify Content, Syntax an Entitty Sentiment using Google Natural Language Processing AI API.  This is a great tool to turn unstructured data into structured tabular data that can be further analyzed.

# %% [markdown]
# ## Vonage Phone Bot
# Send text messages, make phone calls and more using the Vonage API.  Ever wondered about what it takes to become a robo-caller?  No need to wonder any longer.
#
# https://www.vonage.com/communications-apis/

# %% [markdown]
# ## Your Travel API
#
# https://www.partners.skyscanner.net/affiliates/travel-apis
#
# get access to all flight information, including the best prices for flights anywhere in the world.

# %% [markdown]
# ## Twitter API
#
# https://developer.twitter.com/en/docs/twitter-api/tools-and-libraries/v2
#
# Here is an idea: use the twitter api and Google NLP API together and automate a real live twitter troll bot.  Just check Twitter's best practices so that you don't get banned :)
#
# https://blog.twitter.com/common-thread/en/topics/stories/2021/the-secret-world-of-good-bots
